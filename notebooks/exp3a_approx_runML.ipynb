# %%
from time import time
import pandas as pd
import numpy as np
from collections import OrderedDict
import warnings

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import matplotlib.colors

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import (
    AdaBoostClassifier, GradientBoostingClassifier,
    RandomForestClassifier, ExtraTreesClassifier
)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC

from sklearn.preprocessing import StandardScaler

# %%
from plotting_code import apply_style
apply_style("linux")

# %%
def instantiate_model(model_name):
    model = model_name()
    return model

def fit_model(model, X_train, y_train):
    ti = time()
    model = instantiate_model(model)
    model.fit(X_train, y_train)
    fit_time = time() - ti
    return model, fit_time

def append_result_df(df, result_dict):
    df_result_appended = pd.concat([df, pd.DataFrame([result_dict])], ignore_index=True)
    return df_result_appended

def append_model_dict(dic, model_name, model):
    dic[model_name] = model
    return dic

def evaluate_model(model, X, y_act):
    y_pred = model.predict(X)
    acc = accuracy_score(y_act, y_pred)
    f1 = f1_score(y_act, y_pred, average="weighted", zero_division=0)
    precision = precision_score(y_act, y_pred, average="weighted", zero_division=0)
    recall = recall_score(y_act, y_pred, average="weighted", zero_division=0)
    return acc, f1, precision, recall

def fit_evaluate_model(model, model_name, X_train, y_train, X_val, y_val):
    model, fit_time = fit_model(model, X_train, y_train)
    acc_train, f1_train, prec_train, rec_train = evaluate_model(model, X_train, y_train)
    acc_val, f1_val, prec_val, rec_val = evaluate_model(model, X_val, y_val)
    result_dict = {
        'model_name': model_name,
        'model_name_pretty': type(model).__name__,
        'model_params': model.get_params(),
        'fit_time': fit_time,
        'acc_train': acc_train,
        'f1_train': f1_train,
        'precision_train': prec_train,
        'recall_train': rec_train,
        'acc_val': acc_val,
        'f1_val': f1_val,
        'precision_val': prec_val,
        'recall_val': rec_val,
    }
    return model, result_dict

# %% [markdown]
# # Read in featurised dataset

# %%
df_train = pd.read_csv('approx_dataset_splits/app_train_split.csv')
df_test = pd.read_csv('approx_dataset_splits/app_test_split.csv')
df_val = pd.read_csv('approx_dataset_splits/app_val_split.csv')

# %%
df_train.head()
# Out:
#          HMS           Chemical  Temperature  Pressure Crystal_System  \
# 0  P 4/m m m  Nd1Ba1Mn1Fe1O5.45        293.0  0.101325     tetragonal
# 1  P 4/m m m  Nd1Ba1Mn1Fe1O5.17        293.0  0.101325     tetragonal
# 2   P 42 m c  Ca1Mn1Ti1.8V0.2O6        293.0  0.101325     tetragonal
# 3   P 42 m c  Ca1Mn1Ti1.4V0.6O6        293.0  0.101325     tetragonal
# 4   P 42 m c  Ca1Mn1Ti1.2V0.8O6        293.0  0.101325     tetragonal
#
#              formula  all_valence_s_sum  all_valence_s_avg  all_valence_s_dev  \
# 0  Nd1Ba1Mn1Fe1O5.45              10.90           1.153439           0.988158
# 1  Nd1Ba1Mn1Fe1O5.17              10.34           1.127590           0.991827
# 2  Ca1Mn1Ti1.8V0.2O6              12.00           1.200000           0.979796
# 3  Ca1Mn1Ti1.4V0.6O6              12.00           1.200000           0.979796
# 4  Ca1Mn1Ti1.2V0.8O6              12.00           1.200000           0.979796
#
#    all_valence_s_mode  ...  var_gordy_en_max  var_gordy_en_range  \
# 0                 2.0  ...          0.465308            0.259122
# 1                 2.0  ...          0.465308            0.259122
# 2                 2.0  ...          0.252836            0.046650
# 3                 2.0  ...          0.252836            0.046650
# 4                 2.0  ...          0.252836            0.046650
#
#    var_gordy_en_mode  var_mb_en_sum  var_mb_en_avg  var_mb_en_dev  \
# 0           0.465308       0.114709       0.038236       0.027528
# 1           0.465308       0.115040       0.038347       0.027580
# 2           0.232343       0.054324       0.018108       0.023888
# 3           0.232343       0.059880       0.019960       0.022932
# 4           0.232343       0.062658       0.020886       0.022381
#
#    var_mb_en_min  var_mb_en_max  var_mb_en_range  var_mb_en_mode
# 0            0.0       0.063694         0.063694             0.0
# 1            0.0       0.063694         0.063694             0.0
# 2            0.0       0.051546         0.051546             0.0
# 3            0.0       0.051546         0.051546             0.0
# 4            0.0       0.051546         0.051546             0.0
#
# [5 rows x 398 columns]

# %%
df_train["Crystal_System"] = df_train["Crystal_System"].astype("category")
df_test["Crystal_System"] = df_test["Crystal_System"].astype("category")
df_val["Crystal_System"] = df_val["Crystal_System"].astype("category")

label_mapping = dict(enumerate(df_train["Crystal_System"].cat.categories))
print(label_mapping)
# Out:
# {0: 'cubic', 1: 'hexagonal', 2: 'monoclinic', 3: 'orthorhombic', 4: 'tetragonal', 5: 'triclinic', 6: 'trigonal'}

# %%
categories = df_train["Crystal_System"].cat.categories
print(categories)

df_train["Crystal_System"] = df_train["Crystal_System"].cat.set_categories(categories)
df_val["Crystal_System"]   = df_val["Crystal_System"].cat.set_categories(categories)
df_test["Crystal_System"]  = df_test["Crystal_System"].cat.set_categories(categories)

df_train["target"] = df_train["Crystal_System"].cat.codes
df_val["target"]   = df_val["Crystal_System"].cat.codes
df_test["target"]  = df_test["Crystal_System"].cat.codes
# Out:
# Index(['cubic', 'hexagonal', 'monoclinic', 'orthorhombic', 'tetragonal',
#        'triclinic', 'trigonal'],
#       dtype='object')

# %%
# Define which columns are your features (drop non-numeric / target cols)
feature_cols = [col for col in df_train.columns if col not in ['HMS', 'Chemical', 'Crystal_System', 'target', 'formula']]

# Training
X_train_unscaled = df_train[feature_cols].values
y_train = df_train['target'].values

# Validation
X_val_unscaled = df_val[feature_cols].values
y_val = df_val['target'].values

# Test
X_test_unscaled = df_test[feature_cols].values
y_test = df_test['target'].values

# %%
print(feature_cols)
print(X_train_unscaled.shape)  # should be (n_samples, n_features)
print(y_train.shape)  # should be (n_samples,)
print(label_mapping)
# Out:
# ['Temperature', 'Pressure', 'all_valence_s_sum', 'all_valence_s_avg', 'all_valence_s_dev', 'all_valence_s_mode', 'all_unfilled_valence_s_sum', 'all_unfilled_valence_s_avg', 'all_unfilled_valence_s_dev', 'all_unfilled_valence_s_mode', 'all_valence_p_sum', 'all_valence_p_avg', 'all_valence_p_dev', 'all_valence_p_mode', 'all_unfilled_valence_p_sum', 'all_unfilled_valence_p_avg', 'all_unfilled_valence_p_dev', 'all_unfilled_valence_p_mode', 'all_valence_d_sum', 'all_valence_d_avg', 'all_valence_d_dev', 'all_valence_d_max', 'all_valence_d_range', 'all_valence_d_mode', 'all_unfilled_valence_d_sum', 'all_unfilled_valence_d_avg', 'all_unfilled_valence_d_dev', 'all_unfilled_valence_d_min', 'all_unfilled_valence_d_range', 'all_unfilled_valence_d_mode', 'all_unfilled_valence_f_sum', 'all_unfilled_valence_f_avg', 'all_unfilled_valence_f_dev', 'all_valence_total_sum', 'all_valence_total_avg', 'all_valence_total_dev', 'all_valence_total_min', 'all_valence_total_max', 'all_valence_total_range', 'all_valence_total_mode', 'all_unfilled_valence_total_sum', 'all_unfilled_valence_total_avg', 'all_unfilled_valence_total_dev', 'all_unfilled_valence_total_min', 'all_unfilled_valence_total_max', 'all_unfilled_valence_total_range', 'all_unfilled_valence_total_mode', 'var_valence_s_sum', 'var_valence_s_avg', 'var_valence_s_dev', 'var_valence_s_max', 'var_valence_s_range', 'var_valence_s_mode', 'var_unfilled_valence_s_sum', 'var_unfilled_valence_s_avg', 'var_unfilled_valence_s_dev', 'var_unfilled_valence_s_min', 'var_unfilled_valence_s_range', 'var_unfilled_valence_s_mode', 'var_valence_p_sum', 'var_valence_p_avg', 'var_valence_p_dev', 'var_valence_p_max', 'var_valence_p_range', 'var_valence_p_mode', 'var_unfilled_valence_p_sum', 'var_unfilled_valence_p_avg', 'var_unfilled_valence_p_dev', 'var_unfilled_valence_p_min', 'var_unfilled_valence_p_range', 'var_unfilled_valence_p_mode', 'var_valence_d_sum', 'var_valence_d_avg', 'var_valence_d_dev', 'var_valence_d_min', 'var_valence_d_max', 'var_valence_d_range', 'var_valence_d_mode', 'var_unfilled_valence_d_sum', 'var_unfilled_valence_d_avg', 'var_unfilled_valence_d_dev', 'var_unfilled_valence_d_min', 'var_unfilled_valence_d_max', 'var_unfilled_valence_d_range', 'var_unfilled_valence_d_mode', 'var_unfilled_valence_f_sum', 'var_unfilled_valence_f_avg', 'var_unfilled_valence_f_dev', 'var_valence_total_sum', 'var_valence_total_avg', 'var_valence_total_dev', 'var_valence_total_min', 'var_valence_total_max', 'var_valence_total_range', 'var_valence_total_mode', 'var_unfilled_valence_total_sum', 'var_unfilled_valence_total_avg', 'var_unfilled_valence_total_dev', 'var_unfilled_valence_total_min', 'var_unfilled_valence_total_max', 'var_unfilled_valence_total_range', 'var_unfilled_valence_total_mode', 'all_Atomic_Number_sum', 'all_Atomic_Number_avg', 'all_Atomic_Number_dev', 'all_Atomic_Number_min', 'all_Atomic_Number_max', 'all_Atomic_Number_range', 'all_Atomic_Number_mode', 'all_Atomic_Weight_sum', 'all_Atomic_Weight_avg', 'all_Atomic_Weight_dev', 'all_Atomic_Weight_min', 'all_Atomic_Weight_max', 'all_Atomic_Weight_range', 'all_Atomic_Weight_mode', 'all_Period_sum', 'all_Period_avg', 'all_Period_dev', 'all_Period_min', 'all_Period_max', 'all_Period_range', 'all_Period_mode', 'all_group_sum', 'all_group_avg', 'all_group_dev', 'all_group_min', 'all_group_max', 'all_group_range', 'all_group_mode', 'all_Metal_sum', 'all_Metal_avg', 'all_Metal_dev', 'all_Metal_mode', 'all_Nonmetal_sum', 'all_Nonmetal_avg', 'all_Nonmetal_dev', 'all_Nonmetal_mode', 'all_Metalloid_sum', 'all_Metalloid_avg', 'all_Metalloid_dev', 'all_Metalloid_max', 'all_Metalloid_range', 'all_Metalloid_mode', 'all_Mendeleev_Number_sum', 'all_Mendeleev_Number_avg', 'all_Mendeleev_Number_dev', 'all_Mendeleev_Number_min', 'all_Mendeleev_Number_max', 'all_Mendeleev_Number_range', 'all_Mendeleev_Number_mode', 'all_Atomic_Radius_sum', 'all_Atomic_Radius_avg', 'all_Atomic_Radius_dev', 'all_Atomic_Radius_min', 'all_Atomic_Radius_max', 'all_Atomic_Radius_range', 'all_A ...
# (1617, 394)
# (1617,)
# {0: 'cubic', 1: 'hexagonal', 2: 'monoclinic', 3: 'orthorhombic', 4: 'tetragonal', 5: 'triclinic', 6: 'trigonal'}

# %%
print(f"NaNs in X_train: {np.isnan(X_train_unscaled).sum()}")
print(f"NaNs in X_val: {np.isnan(X_val_unscaled).sum()}")

# To see which feature columns have NaNs
nan_cols = df_train[feature_cols].isnull().sum()
print(nan_cols[nan_cols > 0])
# Out:
# NaNs in X_train: 0
# NaNs in X_val: 0
# Series([], dtype: int64)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_unscaled)  # fit only on train
X_val   = scaler.transform(X_val_unscaled)
X_test  = scaler.transform(X_test_unscaled)

# %% [markdown]
# # Running Classification models

# %%
df_classics = pd.DataFrame(columns=[
    'model_name',
    'model_name_pretty',
    'model_params',
    'fit_time',
    'acc_train',
    'f1_train',
    'precision_train',
    'recall_train',
    'acc_val',
    'f1_val',
    'precision_val',
    'recall_val'
])

RANDOM_SEED = 42

classic_model_classes = OrderedDict({
    'dumc': DummyClassifier,
    'lr':   LogisticRegression,
    'abc':  AdaBoostClassifier,
    'gbc':  GradientBoostingClassifier,
    'rfc':  RandomForestClassifier,
    'etc':  ExtraTreesClassifier,
    'svc':  SVC,
    'lsvc': LinearSVC,
    'knc':  KNeighborsClassifier,
})

# Models with seeds and convergence fixes applied
classic_model_names = OrderedDict({
    'dumc': lambda: DummyClassifier(random_state=RANDOM_SEED),
    'lr':   lambda: LogisticRegression(random_state=RANDOM_SEED, max_iter=1000),
    'abc':  lambda: AdaBoostClassifier(random_state=RANDOM_SEED),
    'gbc':  lambda: GradientBoostingClassifier(random_state=RANDOM_SEED),
    'rfc':  lambda: RandomForestClassifier(random_state=RANDOM_SEED),
    'etc':  lambda: ExtraTreesClassifier(random_state=RANDOM_SEED),
    'svc':  lambda: SVC(random_state=RANDOM_SEED),
    'lsvc': lambda: LinearSVC(random_state=RANDOM_SEED, max_iter=5000),
    'knc':  lambda: KNeighborsClassifier(),  # no random_state needed
})

df_classics = pd.DataFrame()
classic_models = OrderedDict()

np.random.seed(RANDOM_SEED)

ti = time()
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for model_name, model in classic_model_names.items():
        print(f'Now fitting and evaluating model {model_name}: {model}')
        model, result_dict = fit_evaluate_model(
            model, model_name, X_train, y_train, X_val, y_val
        )
        df_classics = append_result_df(df_classics, result_dict)
        classic_models = append_model_dict(classic_models, model_name, model)

dt = time() - ti
print(f'Finished fitting {len(classic_models)} models, total time: {dt:0.2f} s')
# Out:
# Now fitting and evaluating model dumc: <function <lambda> at 0x754258402a20>
# Now fitting and evaluating model lr: <function <lambda> at 0x754258402b60>
# Now fitting and evaluating model abc: <function <lambda> at 0x754258402de0>
# Now fitting and evaluating model gbc: <function <lambda> at 0x754258402c00>
# Now fitting and evaluating model rfc: <function <lambda> at 0x754258402e80>
# Now fitting and evaluating model etc: <function <lambda> at 0x754258402f20>
# Now fitting and evaluating model svc: <function <lambda> at 0x754258402fc0>
# Now fitting and evaluating model lsvc: <function <lambda> at 0x754258403060>
# Now fitting and evaluating model knc: <function <lambda> at 0x754258403100>
# Finished fitting 9 models, total time: 148.80 s

# %%
# Sort in order of increasing validation r2 score
df_classics = df_classics.sort_values('f1_val', ignore_index=True)
df_classics
# Out:
#   model_name           model_name_pretty  \
# 0       dumc             DummyClassifier
# 1        abc          AdaBoostClassifier
# 2        svc                         SVC
# 3        knc        KNeighborsClassifier
# 4         lr          LogisticRegression
# 5       lsvc                   LinearSVC
# 6        rfc      RandomForestClassifier
# 7        gbc  GradientBoostingClassifier
# 8        etc        ExtraTreesClassifier
#
#                                         model_params   fit_time  acc_train  \
# 0  {'constant': None, 'random_state': 42, 'strate...   0.002415   0.313544
# 1  {'algorithm': 'deprecated', 'estimator': None,...   1.867264   0.609153
# 2  {'C': 1.0, 'break_ties': False, 'cache_size': ...   0.238274   0.761286
# 3  {'algorithm': 'auto', 'leaf_size': 30, 'metric...   0.003134   0.787879
# 4  {'C': 1.0, 'class_weight': None, 'dual': False...  26.051628   0.863327
# 5  {'C': 1.0, 'class_weight': None, 'dual': 'auto...  40.341690   0.889301
# 6  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...   1.290099   0.988250
# 7  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...  77.579434   0.977118
# 8  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   0.392802   0.988250
#
#    f1_train  precision_train  recall_train   acc_val    f1_val  precision_val  \
# 0  0.149686         0.098310      0.313544  0.273973  0.117838       0.075061
# 1  0.603838         0.609435      0.609153  0.573059  0.566155       0.580595
# 2  0.758634         0.769532      0.761286  0.655251  0.647743       0.662240
# 3  0.786155         0.786183      0.787879  0.668950  0.665711       0.672764
# 4  0.862694         0.865129      0.863327  0.698630  0.695780       0.703030
# 5  0.888784         0.890823      0.889301  0.712329  0.709763       0.718819
# 6  0.988252         0.988317      0.988250  0.808219  0.807297       0.809688
# 7  0.977126         0.977365      0.977118  0.817352  0.816176       0.817834
# 8  0.988238         0.988421      0.988250  0.831050  0.830317       0.831078
#
#    recall_val
# 0    0.273973
# 1    0.573059
# 2    0.655251
# 3    0.668950
# 4    0.698630
# 5    0.712329
# 6    0.808219
# 7    0.817352
# 8    0.831050

# %% [markdown]
# # Assessing best classification model

# %%
# Find the best-performing model that we have tested
best_row = df_classics.iloc[-1, :].copy()

# Get the model type and model parameters
model_name = best_row['model_name']
model_params = best_row['model_params']

# Instantiate the model again using the parameters
model = classic_model_classes[model_name](**model_params)
print(model)
print(model.get_params())
# Out:
# ExtraTreesClassifier(random_state=42)
# {'bootstrap': False, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
from tqdm import tqdm
# Combine Unscaled train and val together
X_train_final = np.concatenate((X_train_unscaled, X_val_unscaled), axis=0)
y_train_final = np.concatenate((y_train, y_val), axis=0)
# Scale on the train_final and fit the test

scaler = StandardScaler()
X_train_final = scaler.fit_transform(X_train_final)  # fit only on train
X_test  = scaler.transform(X_test_unscaled)

print(X_train_final.shape)

ti = time()

model.fit(X_train_final, y_train_final)

dt = time() - ti
print(f'Finished fitting best model, total time: {dt:0.2f} s')

y_act_test = y_test
y_pred_test = model.predict(X_test)

acc, f1, precision, recall = evaluate_model(model, X_test, y_test)
print('Accuracy',acc)
print('F1', f1)
print('Precision', precision)
print('Recall', recall)
# Out:
# (2055, 394)
# Finished fitting best model, total time: 0.49 s
# Accuracy 0.8596491228070176
# F1 0.8621681206768532
# Precision 0.8713612239154033
# Recall 0.8596491228070176

# %%
# Get class labels from label mapping
class_labels = [label_mapping[i] for i in sorted(label_mapping.keys())]
print(classification_report(y_test, y_pred_test, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#        cubic       0.85      0.91      0.88        32
#    hexagonal       0.81      0.81      0.81        16
#   monoclinic       0.68      0.82      0.74        28
# orthorhombic       0.86      0.88      0.87        48
#   tetragonal       1.00      0.76      0.86        29
#    triclinic       0.57      0.67      0.62         6
#     trigonal       0.95      0.91      0.93        69
#
#     accuracy                           0.86       228
#    macro avg       0.82      0.82      0.82       228
# weighted avg       0.87      0.86      0.86       228

# %%
custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("custom", ["#fafafa", "#993bff", "#361a54"])

# Normalised version (shows % of each true class correctly predicted)
cm_norm = confusion_matrix(y_test, y_pred_test, normalize='true')
cm_percent = (cm_norm * 100).round(1)  # convert to percentages rounded to 1dp

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_percent, display_labels=class_labels)
disp.plot(ax=ax, cmap=custom_cmap, colorbar=True, xticks_rotation=45)
disp.im_.colorbar.set_label('Recall (%)')
    
plt.tight_layout()
plt.savefig('outputs/confusion_matrix_etc_normalised.png', bbox_inches='tight')
plt.show()

# %%
def plot_feature_importances(model, feature_names, top_n=None):
    if not hasattr(model, "feature_importances_"):
        raise ValueError(f"Model type {type(model)} does not have feature_importances_.")
    
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]
    
    if top_n is not None:
        indices = indices[:top_n]
    
    plt.figure(figsize=(10, 7))
    plt.bar(range(len(indices)), importances[indices], color = '#e55c30')
    plt.xticks(range(len(indices)), np.array(feature_names)[indices], rotation=45, ha="right")
    plt.ylabel("Feature Importance")
    plt.tight_layout()
    plt.show()

plot_feature_importances(model, feature_cols, top_n = 15)

# %% [markdown]
# # SHAP Values for analysis

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# Get class names - handle both list and dict
if isinstance(label_mapping, dict):
    class_names = [label_mapping[i] for i in range(7)]
else:
    class_names = label_mapping

# Calculate mean absolute SHAP values for each class
mean_shap_values = []
for i in range(7):  # 7 classes
    class_shap = shap_values[:, :, i]
    mean_shap = np.abs(class_shap).mean(axis=0)
    mean_shap_values.append(mean_shap)

# Create DataFrame with class names as index
shap_df = pd.DataFrame(mean_shap_values, columns=feature_cols, index=class_names).T

# Calculate total importance across all classes to find top 5 features
shap_df['total'] = shap_df.sum(axis=1)
top_5_features = shap_df.nlargest(5, 'total').drop('total', axis=1)

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=256):
    new_cmap = mcolors.LinearSegmentedColormap.from_list(
        f"trunc({cmap.name},{minval:.2f},{maxval:.2f})",
        cmap(np.linspace(minval, maxval, n))
    )
    return new_cmap

cmap_trunc = truncate_colormap(cm.inferno, minval=0.1, maxval=0.9)

# %%
fig, ax = plt.subplots(figsize=(10, 7.5))

ax = top_5_features.plot(
    kind='bar',
    ax=ax,
    width=0.85,
    colormap=cmap_trunc,
    edgecolor='black',
    linewidth=0.3
)

hatches = ['', '\\',  '-', 'xx', '++', 'o',  '.',]

# Rotate x labels properly
ax.set_xticklabels(ax.get_xticklabels(), rotation=15, ha='right')

# Labels
ax.set_ylabel('Mean |SHAP value|')
ax.set_xlabel('Features')

# Improve grid (subtle, not overwhelming)
ax.yaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)
ax.set_axisbelow(True)

# Optional: reduce visual noise from hatching
use_hatching = True

if use_hatching:
    bars = ax.containers
    for i, container in enumerate(bars):
        for bar in container:
            bar.set_hatch(hatches[i])
            bar.set_edgecolor('white')
            bar.set_linewidth(0.2)

ax.legend(
    ncol=1,
    loc='upper right',
)

plt.tight_layout()
plt.savefig('outputs/SHAP_mean.png', bbox_inches='tight')
plt.show()

# %%
top5_names = [
    'all_Atomic_Radius_dev',
    'all_pauling_en_min',
    'var_Covalent_Radius_dev',
    'var_pauling_en_min',
    'all_ionic_radius_sum'
]

# overall_rank must already be built (summed mean|SHAP| across all 7 classes):
overall_rank = shap_df.drop(columns='total', errors='ignore').copy()
overall_rank['total'] = overall_rank.sum(axis=1)
overall_rank = overall_rank.sort_values('total', ascending=False)
total_importance = overall_rank['total'].sum()
overall_rank['pct_of_total'] = 100 * overall_rank['total'] / total_importance

print("Overall (all crystal systems combined) importance:")
for name in top5_names:
    row = overall_rank.loc[name]
    rank = overall_rank.index.get_loc(name) + 1
    print(f"  {name}: total={row['total']:.4f}, {row['pct_of_total']:.2f}% of all importance (rank {rank}/{len(overall_rank)})")
# Out:
# Overall (all crystal systems combined) importance:
#   all_Atomic_Radius_dev: total=0.0203, 0.92% of all importance (rank 1/394)
#   all_pauling_en_min: total=0.0184, 0.83% of all importance (rank 2/394)
#   var_Covalent_Radius_dev: total=0.0182, 0.82% of all importance (rank 3/394)
#   var_pauling_en_min: total=0.0181, 0.82% of all importance (rank 4/394)
#   all_ionic_radius_sum: total=0.0179, 0.81% of all importance (rank 5/394)

# %%
import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# QUANTITATIVE: Gini coefficient of feature importance
# ============================================================
def gini(importances):
    sorted_imp = np.sort(importances)
    n = len(sorted_imp)
    cum = np.cumsum(sorted_imp)
    return (n + 1 - 2 * np.sum(cum) / cum[-1]) / n

importances = overall_rank['total'].values
g = gini(importances)
print(f"Gini coefficient of feature importance: {g:.3f}")
print(f"(0 = perfectly even importance across all {len(importances)} features, "
      f"1 = importance concentrated in a single feature)")

# ============================================================
# LORENZ CURVE
# cumulative % of features (x) vs cumulative % of importance (y)
# ============================================================
sorted_imp = np.sort(importances)  # ascending, so curve bows below the diagonal
cum_imp_pct = 100 * np.cumsum(sorted_imp) / sorted_imp.sum()
cum_feat_pct = 100 * np.arange(1, len(sorted_imp) + 1) / len(sorted_imp)

# prepend origin (0,0) so the curve starts at the corner
cum_feat_pct = np.insert(cum_feat_pct, 0, 0)
cum_imp_pct = np.insert(cum_imp_pct, 0, 0)

fig, ax = plt.subplots(figsize=(6, 6))  # square, matches Lorenz curve convention

ax.plot(cum_feat_pct, cum_imp_pct, color="#000000", linewidth=2, label='Lorenz curve')
ax.plot([0, 100], [0, 100], color='k', linestyle='--', linewidth=1, alpha=0.6, label='Perfect equality')

# shade the area between the diagonal and the curve (visualizes the Gini area)
ax.fill_between(cum_feat_pct, cum_imp_pct, cum_feat_pct, color='#993bff', alpha=0.15)

ax.set_xlabel('Cumulative % of features (least to most important)')
ax.set_ylabel('Cumulative % of total SHAP importance')
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
ax.set_aspect('equal')
ax.legend(loc='upper left', frameon=False)

ax.text(
    0.97, 0.05, f'Gini = {g:.3f}',
    transform=ax.transAxes, ha='right', va='bottom',
    fontsize=11
)

plt.tight_layout()
plt.savefig('outputs/lorenz_curve_feature_importance.png', bbox_inches='tight')
plt.show()
# Out:
# Gini coefficient of feature importance: 0.409
# (0 = perfectly even importance across all 394 features, 1 = importance concentrated in a single feature)

# %%
X_test_df = pd.DataFrame(X_test, columns=feature_cols)

shap_values = explainer(X_test_df)

# %%
for i in range(7):
    shap_values_cat = shap_values[..., i]
    
    mean_abs = np.abs(shap_values_cat.values).mean(axis=0)
    top10_idx = np.argsort(mean_abs)[-10:]
    
    shap_top10 = shap.Explanation(
        values=shap_values_cat.values[:, top10_idx],
        base_values=shap_values_cat.base_values,
        data=shap_values_cat.data[:, top10_idx] if shap_values_cat.data is not None else None,
        feature_names=[feature_cols[j] for j in top10_idx] 
    )

    fig = plt.figure(figsize=(6, 6))  # square figure BEFORE calling beeswarm
    shap.plots.beeswarm(shap_top10, max_display=10, color=cmap_trunc, show=False)
    ax = plt.gca()
    ax.set_xlabel("SHAP value (impact on model output)")
    ax.set_title(f"Class: {label_mapping[i]}")
    ax.set_xlim(-0.032,0.042)
    for label in ax.get_yticklabels():
        label.set_color('black')
    plt.tight_layout()
    plt.savefig(f'outputs/beeswarm_class_{label_mapping[i]}.png', bbox_inches='tight')
    plt.show()

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.gridspec import GridSpec

alphabet = ["a", "b", "c", "d", "e", "f", "g", "h"]

X_test_df = pd.DataFrame(X_test, columns=feature_cols)
shap_values = explainer(X_test_df)

# ── Step 1: save each beeswarm individually ───────────────────────────────────
bee_paths = []
for i in range(7):
    shap_values_cat = shap_values[..., i]
    mean_abs = np.abs(shap_values_cat.values).mean(axis=0)
    top10_idx = np.argsort(mean_abs)[-10:]

    shap_top10 = shap.Explanation(
        values=shap_values_cat.values[:, top10_idx],
        base_values=shap_values_cat.base_values,
        data=shap_values_cat.data[:, top10_idx] if shap_values_cat.data is not None else None,
        feature_names=[feature_cols[j] for j in top10_idx]
    )

    fig, ax = plt.subplots(figsize=(8, 6))
    plt.sca(ax)
    shap.plots.beeswarm(shap_top10, max_display=10, color=cmap_trunc, show=False)
    ax = plt.gca()
    ax.set_xlabel("SHAP value (impact on model output)")
    ax.set_title(f"({alphabet[i]}) Class: {label_mapping[i]}", fontweight='bold')
    ax.set_xlim(-0.032, 0.042)
    for label in ax.get_yticklabels():
        label.set_color('black')
    plt.tight_layout()
    path = f'outputs/_tmp_bee_{i}.png'
    plt.savefig(path, dpi=150, bbox_inches='tight')
    plt.close()
    bee_paths.append(path)

# ── Step 2: stitch into 2-column grid ────────────────────────────────────────
n_cols = 2
n_rows = (7 + n_cols - 1) // n_cols  # = 4

bee_imgs = [mpimg.imread(p) for p in bee_paths]

fig = plt.figure(figsize=(18, n_rows * 7))
gs = GridSpec(n_rows, n_cols, figure=fig, hspace=0.05, wspace=0.05)

for i, img in enumerate(bee_imgs):
    ax = fig.add_subplot(gs[i // n_cols, i % n_cols])
    ax.imshow(img)
    ax.axis('off')

# hide the empty 8th cell
fig.add_subplot(gs[n_rows - 1, n_cols - 1]).set_visible(False)

plt.savefig('outputs/SHAP_beeswarm_all.png', bbox_inches='tight')
plt.show()

# ── Step 3: clean up temp files ───────────────────────────────────────────────
for p in bee_paths:
    os.remove(p)

# %%
from tqdm import tqdm
seeds = [42, 123, 456, 789, 1024, 2024, 314, 99, 7, 2000]
models_to_evaluate = ['etc', 'rfc', 'lr', 'lsvc', 'dumc']
seed_rows = []

for seed in tqdm(seeds, desc='Seeds'):
    for model_name in tqdm(models_to_evaluate, desc='Models', leave=False):
        
        model_params = df_classics.loc[df_classics['model_name'] == model_name].iloc[0]['model_params'].copy()
        model_params['random_state'] = seed
        
        model = classic_model_classes[model_name](**model_params)
        model.fit(X_train_final, y_train_final)
        
        acc, f1, precision, recall = evaluate_model(model, X_test, y_test)
        
        seed_rows.append({
            'seed':      seed,
            'model':     model_name,
            'test_acc':  acc,
            'test_f1':   f1,
            'test_prec': precision,
            'test_rec':  recall,
        })

seed_df = pd.DataFrame(seed_rows)

summary = seed_df.groupby('model').agg(
    acc_mean=('test_acc', 'mean'),
    acc_std= ('test_acc', 'std'),
    f1_mean= ('test_f1',  'mean'),
    f1_std=  ('test_f1',  'std'),
).round(4)

print(summary)

seed_df['feature_set'] = 'approx' 
seed_df.to_csv('results/approx_seed_results.csv', index=False)
# Out:
# Seeds: 100%|██████████| 10/10 [14:00<00:00, 84.06s/it]
#        acc_mean  acc_std  f1_mean  f1_std
# model
# dumc     0.3026   0.0000   0.1406  0.0000
# etc      0.8531   0.0043   0.8551  0.0046
# lr       0.7105   0.0000   0.7067  0.0000
# lsvc     0.7368   0.0000   0.7348  0.0000
# rfc      0.8522   0.0077   0.8544  0.0075
